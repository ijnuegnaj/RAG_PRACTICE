# %% [markdown]
# <a href="https://colab.research.google.com/github/ijnuegnaj/RAG_PRACTICE/blob/practice1/LangChain_%EC%BB%B4%ED%8F%AC%EB%84%8C%ED%8A%B8_%EC%98%88%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## 1. 모델과 파서

- 모델 : gpt .. < 다양한 버전의 모델에 어떻게 저근, 대화를 어떻게 세팅할 수 있는지
- 파서 : 내가 원하는 포맷으로 api의 답변을 컨트롤할 수 있는 모듈
# Out:
#   File "/tmp/ipython-input-140473077.py", line 3
#     - 모델 : gpt .. < 다양한 버전의 모델에 어떻게 저근, 대화를 어떻게 세팅할 수 있는지
#     ^
# SyntaxError: illegal target for annotation

# %%
# !pip install -q python-dotenv openai==0.28
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 kB 6.7 MB/s eta 0:00:00

# %%
import os
from google.colab import userdata

# %%
import os
from google.colab import userdata

os.environ[OPENAI_API_KEY] = userdata.get('OPENAI_API_KEY')
# Out:
# ---------------------------------------------------------------------------
# SecretNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-2280327720.py in <cell line: 0>()
#       2 from google.colab import userdata
#       3
# ----> 4 os.environ[OPENAI_API_KEY] = userdata.get('OPENAI_API_KEY')
#
# /usr/local/lib/python3.11/dist-packages/google/colab/userdata.py in get(key)
#      66     raise TimeoutException(key)
#      67   if not resp.get('exists', False):
# ---> 68     raise SecretNotFoundError(key)
#      69   if not resp.get('access', False):
#      70     raise NotebookAccessError(key)
#
# SecretNotFoundError: Secret OPENAI_API_KEY does not exist.

# %%
os.environ[OPENAI_API_KEY] = userdata.get('OPENAI_API_KEY')
# Out:
# ---------------------------------------------------------------------------
# SecretNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-1968063064.py in <cell line: 0>()
# ----> 1 os.environ[OPENAI_API_KEY] = userdata.get('OPENAI_API_KEY')
#
# /usr/local/lib/python3.11/dist-packages/google/colab/userdata.py in get(key)
#      66     raise TimeoutException(key)
#      67   if not resp.get('exists', False):
# ---> 68     raise SecretNotFoundError(key)
#      69   if not resp.get('access', False):
#      70     raise NotebookAccessError(key)
#
# SecretNotFoundError: Secret OPENAI_API_KEY does not exist.
